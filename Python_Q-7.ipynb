# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_nasa.csv')

# %%
df
# Out:
#           name     id nametype               recclass      mass        year  \
# 0       Aachen      1    Valid                     L5      21.0  1880-01-01
# 1       Aarhus      2    Valid                     H6     720.0  1951-01-01
# 2         Abee      6    Valid                    EH4  107000.0  1952-01-01
# 3     Acapulco     10    Valid            Acapulcoite    1914.0  1976-01-01
# 4      Achiras    370    Valid                     L6     780.0  1902-01-01
# ..         ...    ...      ...                    ...       ...         ...
# 995   Tirupati  24009    Valid                     H6     230.0  1934-01-01
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0  2011-01-01
# 997      Tjabe  24011    Valid                     H6   20000.0  1869-01-01
# 998   Tjerebon  24012    Valid                     L5   16500.0  1922-01-01
# 999  Tomakovka  24019    Valid                    LL6     600.0  1905-01-01
#
#        reclat    reclong            coordinates
# ...

# %% [markdown]
# ## Get all the Earth meteorites that fell before the year 2000

# %%
df['year'] = pd.to_datetime(df['year'])

# %%
meteorites = df[df['year'].dt.year < 2000]
meteorites
# Out:
#           name     id nametype     recclass      mass       year    reclat  \
# 0       Aachen      1    Valid           L5      21.0 1880-01-01  50.77500
# 1       Aarhus      2    Valid           H6     720.0 1951-01-01  56.18333
# 2         Abee      6    Valid          EH4  107000.0 1952-01-01  54.21667
# 3     Acapulco     10    Valid  Acapulcoite    1914.0 1976-01-01  16.88333
# 4      Achiras    370    Valid           L6     780.0 1902-01-01 -33.16667
# ..         ...    ...      ...          ...       ...        ...       ...
# 994   Timochin  24004    Valid           H5   65500.0 1807-01-01  54.50000
# 995   Tirupati  24009    Valid           H6     230.0 1934-01-01  13.63333
# 997      Tjabe  24011    Valid           H6   20000.0 1869-01-01  -7.08333
# 998   Tjerebon  24012    Valid           L5   16500.0 1922-01-01  -6.66667
# 999  Tomakovka  24019    Valid          LL6     600.0 1905-01-01  47.85000
#
#        reclong            coordinates
# ...

# %% [markdown]
# ## Get all the earth meteorites co-ordinates who fell before the year 1970

# %%
coordinates = df[df['year'].dt.year < 1970][['name','reclong','reclat', 'coordinates']]

# %%
coordinates
# Out:
#           name    reclong    reclat            coordinates
# 0       Aachen    6.08333  50.77500      [6.08333, 50.775]
# 1       Aarhus   10.23333  56.18333   [10.23333, 56.18333]
# 2         Abee -113.00000  54.21667       [-113, 54.21667]
# 4      Achiras  -64.95000 -33.16667    [-64.95, -33.16667]
# 5     Adhi Kot   71.80000  32.10000           [71.8, 32.1]
# ..         ...        ...       ...                    ...
# 994   Timochin   35.20000  54.50000           [35.2, 54.5]
# 995   Tirupati   79.41667  13.63333   [79.41667, 13.63333]
# 997      Tjabe  111.53333  -7.08333  [111.53333, -7.08333]
# 998   Tjerebon  106.58333  -6.66667  [106.58333, -6.66667]
# 999  Tomakovka   34.76667  47.85000      [34.76667, 47.85]
#
# [763 rows x 4 columns]

# %%
plt.figure(figsize=(10, 10))
plt.scatter(coordinates['reclong'], coordinates['reclat'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Earth Meteorites Coordinates Before 1970')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

# %%
mass = df[df['mass'] > 10000]

# %%
mass
# Out:
#            name     id nametype   recclass      mass       year    reclat  \
# 2          Abee      6    Valid        EH4  107000.0 1952-01-01  54.21667
# 7          Agen    392    Valid         H5   30000.0 1814-01-01  44.21667
# 11          Aïr    424    Valid         L6   24000.0 1925-01-01  19.08333
# 16      Akyumak    433    Valid  Iron, IVA   50000.0 1981-01-01  39.91667
# 27   Alfianello    466    Valid         L6  228000.0 1883-01-01  45.26667
# ..          ...    ...      ...        ...       ...        ...       ...
# 991   Tieschitz  23989    Valid     H/L3.6   28000.0 1878-01-01  49.60000
# 992      Tilden  23998    Valid         L6   74800.0 1927-01-01  38.20000
# 994    Timochin  24004    Valid         H5   65500.0 1807-01-01  54.50000
# 997       Tjabe  24011    Valid         H6   20000.0 1869-01-01  -7.08333
# 998    Tjerebon  24012    Valid         L5   16500.0 1922-01-01  -6.66667
#
#        reclong            coordinates
# 2   -113.00000       [-113, 54.21667]
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist(mass['mass'], bins=10)
plt.xlabel('Mass (kg)*10^7')
plt.ylabel('Count of Meteorites')
plt.title('Earth Meteorites Mass > 10000kg')
plt.grid(True)
plt.show()

# %%
mass['mass'].min()
# Out:
# 10200.0

# %%
mass['mass'].max()
# Out:
# 23000000.0
